# %%
import add_path

from toolkit.paths import *
from toolkit.utils.pack_data import filter_and_zip

# %%
source_dir = PROCESSED_DATA_CACHE_DIR
accept_files = []  # Accept files patterns
filter_files = ["csd.nc"]  # Reject files patterns

# Create zip file directly, skipping temporary directory
zip_path = source_dir.parent / f"{source_dir.name}.zip"
filter_and_zip(source_dir, zip_path, accept_files, filter_files)
# Out:
# Zip file created: C:\Users\ziaochen\projects\neuroscience\Analyzing_Allen_Visual_Coding_Neuropixels_Dataset\cache\processed_data_cache.zip

# %%
source_dir = OUTPUT_BASE_DIR
accept_files = []  # Accept files patterns
filter_files = []  # Reject files patterns

# Create zip file directly, skipping temporary directory
zip_path = source_dir.parent / f"{source_dir.name}.zip"
filter_and_zip(source_dir, zip_path, accept_files, filter_files)
